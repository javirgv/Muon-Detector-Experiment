# %%
import serial
from serial.tools import list_ports
import json
import numpy as np

# %%
# Check what COM port it is on
from serial.tools import list_ports
for p in list_ports.comports():
    print(p)
# Out:
# COM3 - USB Serial Device (COM3)
# COM1 - Communications Port (COM1)

# %%
# Set up a connection
ser = serial.Serial(
    "com3",
    baudrate = 115200,
    timeout = 1  # seconds - timeout needed so that device is not blocked indefinetly if it has no data
)

# %%
# String to byte conversion
def data(mystring):
    return bytes(mystring+'\n','utf-8')

# %%
delays = np.arange(500, 10000, 200)   # from 0.5 to 10 us in steps of 0.2

for delay in delays:
    js = json.dumps(dict(pulseWidth=20, interPulseDelay=float(delay), pulseInterval=100))   # delay is end-to-start difference
    
    ser.write(data(js))
    
#ser.readlines()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 interval_times = np.arange(500, 10000, 200)   # from 0.5 to 10 us in steps of 0.2
#       3 for delay in interval_times:
# ----> 4     js = json.dumps(dict(pulseWidth=20, interPulseDelay=delay, pulseInterval=100))   # delay is end-to-start difference
#       6     ser.write(data(js))
#
# File C:\ProgramData\Anaconda3\lib\json\__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
# ...

# %%
ser.close()
