# %%
# Check what COM port it is on
from serial.tools import list_ports
for p in list_ports.comports():
    print(p)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Check what COM port it is on
# ----> 2 from serial.tools import list_ports
#       3 for p in list_ports.comports():
#       4     print(p)
#
# ModuleNotFoundError: No module named 'serial'

# %%
import serial

# Set up a connection
ser = serial.Serial(
    "com3",
    baudrate = 115200,
    timeout = 1  # seconds - timeout needed so that device is not blocked indefinetly if it has no data
)

# %%
import json

js = json.dumps(dict(pulseWidth=100, interPulseDelay=200, pulseInterval=100))

# %%
import serial
import json

ser = serial.Serial(
  "com3",
  baudrate=115200,
  timeout=1
)  

print(ser.readlines())  # Maybe get device startup string if fast enough!

def data(mystring):
  return bytes(mystring+'\n','utf-8')

js = json.dumps(dict(pulseWidth=100, interPulseDelay=100, pulseInterval=100)

ser.write(data(js))

ser.readlines()
